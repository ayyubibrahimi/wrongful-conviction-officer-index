# %%
import pandas as pd
import re
from lib import clean_column_names

# %%
def split_officer_name(name):
    if pd.isna(name) or not isinstance(name, str):
        return pd.Series({'first_name': None, 'middle_name': None, 'last_name': None, 'suffix': None})
    
    name = name.strip().rstrip('.,')
    
    suffixes = {'JR', 'SR', 'II', 'III', 'IV', 'V'}
    
    suffix = None
    for s in suffixes:
        if name.upper().endswith(' ' + s) or name.upper().endswith(',' + s):
            suffix = s
            name = name[:-(len(s)+1)].strip().rstrip(',')
            break
    
    parts = re.split(r',\s*|\s+', name)
    
    if ',' in name:  
        last_name = parts[0].title()
        first_name = parts[1].title() if len(parts) > 1 else None
        middle_name = ' '.join(parts[2:]).title() or None
    elif name.isupper():  
        last_name = parts[0].title()
        first_name = parts[1].title() if len(parts) > 1 else None
        middle_name = ' '.join(parts[2:]).title() or None
    else:  
        first_name = parts[0].title()
        last_name = parts[-1].title()
        middle_name = ' '.join(parts[1:-1]).title() or None
    
    return pd.Series({'first_name': first_name, 'middle_name': middle_name, 'last_name': last_name, 'suffix': suffix})

df = pd.read_csv("../../post-extract/data/output/all_officers_output.csv")

name_parts = df['Officer Name'].apply(split_officer_name)

df[['first_name', 'middle_name', 'last_name', 'suffix']] = name_parts


def clean_matching_data(df):
    df.loc[:, "first_name"] = df.first_name.str.lower().str.strip()
    df.loc[:, "middle_name"] = df.middle_name.str.lower().str.strip()
    df.loc[:, "last_name"] = df.last_name.str.lower().str.strip()
    df.loc[:, "suffix"] = df.suffix.str.lower().str.strip()

    df.loc[:, "agency_name"] = (df.agency_name
                                .str.lower()
                                .str.strip()
                                .str.replace(r"\s+", "-", regex=True)
                                .str.replace(r"(\w{1})\.(\w{1})\.", r"\1\2", regex=True)
    )
    return df 

def filter_for_orleans_officers(df):
    grouped = df.groupby('person_id')
    
    def has_orleans(group):
        return group['agency_name'].str.contains('orleans', case=False).any()

    orleans_officers = grouped.filter(has_orleans)
    
    return orleans_officers


print(f"Number of rows before filtering: {len(df)}")
df = df.pipe(clean_column_names).pipe(clean_matching_data).pipe(filter_for_orleans_officers)
df
# Out:
# Number of rows before filtering: 671
#                               hash_id                         person_id  \
# 15   f1f787032861e3c306e6c4593ee42cac  4715216ab590dde009e36d953a27ba20
# 16   fc11cc693d7bd1d68d0af761e84fdd53  67abadc2d1d03144a6a580777aeabdfa
# 18   15e0a96b310deb691687a19e685bde47  da0100ca799212ad1943f0af0ded62fe
# 19   92040c696328862497ca68c3dc1a530e  da0100ca799212ad1943f0af0ded62fe
# 20   fe4d56f45be7e7b5d281759898e8a23e  4002f7918e096b0b87198a354596258e
# ..                                ...                               ...
# 660  f01b4cb7837e365c1169edd6b2dbe28b  057776af2a606666781c3b79ff840514
# 663  11eaa142d0fc50188ad5155fe17fd9fc  cfd6710c4b7defe302d5e88eeeb44f66
# 664  62229b9e62ef31a4a19578aa8da8235d  c588dd666c8b97378518928cb15242cd
# 665  aef22f8e11bdadaf7bc8178ae725f0ac  c588dd666c8b97378518928cb15242cd
# 666  1fe3fd4beac173d6d98c83dfc90fe647  1b5887edaf0965dc40469a127e0282d2
#
#                       officer_name officer_sex           agency_name  \
# 15   AGUILLARD, DYNASTY JARANEISHA      Female        new-orleans-pd
# 16                     ALLEN, KIRK        Male        new-orleans-pd
# 18          ARROYO, STEVEN RICHARD        Male        new-orleans-pd
# 19          ARROYO, STEVEN RICHARD        Male  st-tammany-parish-so
# 20     BRADFORD, HENRY GERARD, SR.        Male        new-orleans-pd
# ..                             ...         ...                   ...
# 660                     CAHN, MIKE        Male        new-orleans-pd
# 663           THOMAS, JOHN DERRICK        Male        new-orleans-pd
# 664                   BLAIR, CRAIG        Male        new-orleans-pd
# 665                   BLAIR, CRAIG        Male        new-orleans-pd
# 666              HARRISON, MICHAEL        Male        new-orleans-pd
#
#         status   hire_date separation_date reason_for_separation  \
# 15         NaN  11/10/2019             NaN                   NaN
# 16   FULL-TIME    8/8/1981        5/8/2016                   NaN
# 18   FULL-TIME    1/8/1989      12/19/2023               RETIRED
# 19     RETIRED         NaN             NaN                   NaN
# 20     RETIRED         NaN             NaN                   NaN
# ..         ...         ...             ...                   ...
# 660        NaN    12/11/99             NaN                   NaN
# 663  FULL-TIME   8/19/1991      12/11/2021                 Other
# 664  FULL-TIME   6/14/1981             NaN                   NaN
# 665    RETIRED   6/14/1981      10/22/2015                   NaN
# 666    RETIRED  10/10/1991       1/26/2019                   NaN
#
#                                       filename  page_number first_name  \
# 15        LA_Peace_Officer_Reports_7_12_24.pdf            2    dynasty
# 16        LA_Peace_Officer_Reports_7_12_24.pdf            3       kirk
# 18        LA_Peace_Officer_Reports_7_12_24.pdf            5     steven
# 19        LA_Peace_Officer_Reports_7_12_24.pdf            5     steven
# 20        LA_Peace_Officer_Reports_7_12_24.pdf            6      henry
# ..                                         ...          ...        ...
# 660  LA_Peace_Officer_Reports_7_12_24_pt.4.pdf           18       mike
# 663  LA_Peace_Officer_Reports_7_12_24_pt.4.pdf           22       john
# 664  LA_Peace_Officer_Reports_7_12_24_pt.4.pdf           24      craig
# 665  LA_Peace_Officer_Reports_7_12_24_pt.4.pdf           24      craig
# 666  LA_Peace_Officer_Reports_7_12_24_pt.4.pdf           25    michael
#
#     middle_name  last_name suffix
# 15   jaraneisha  aguillard   None
# 16         None      allen   None
# 18      richard     arroyo   None
# 19      richard     arroyo   None
# 20       gerard   bradford     sr
# ..          ...        ...    ...
# 660        None       cahn   None
# 663     derrick     thomas   None
# 664        None      blair   None
# 665        None      blair   None
# 666        None   harrison   None
#
# [317 rows x 15 columns]

# %%
df.to_csv("../data/output/post_clean.csv", index=False)
